# %%
import pandas as pd
import os
from Models.functions.reports import showReports

# %%
showReports(task='age')
# Out:
# age esic
#               f1-score  precision    recall  support       roc  accuracy
# a17-29        0.452459   0.511685  0.405521  22460.0  0.751935  0.548159
# a31-42        0.504247   0.507603  0.500936  34721.0  0.646743  0.548159
# a43-80        0.641028   0.599631  0.688564  34495.0  0.783443  0.548159
# micro avg     0.548159   0.548159  0.548159  91676.0  0.727382  0.548159
# macro avg     0.532578   0.539640  0.531674  91676.0  0.727382  0.548159
# weighted avg  0.543026   0.543231  0.548159  91676.0  0.727382  0.548159
# age brblogset
#               f1-score  precision    recall  support       roc  accuracy
# a10-25        0.197425   0.398844  0.131179    526.0  0.598086  0.434407
# a26-40        0.519311   0.418919  0.682987    817.0  0.559831  0.434407
# a40+          0.421613   0.480903  0.375339    738.0  0.626239  0.434407
# micro avg     0.434407   0.434407  0.434407   2081.0  0.595061  0.434407
# ...

# %%
showReports('gender')
# Out:
# gender esic
#               f1-score  precision    recall  support       roc  accuracy
# Feminino      0.011500   0.461538  0.005822  40189.0  0.496639  0.587265
# Masculino     0.739182   0.587923  0.995234  57278.0  0.503361  0.587265
# micro avg     0.587265   0.587265  0.587265  97467.0  0.500002  0.587265
# macro avg     0.375341   0.524731  0.500528  97467.0  0.500002  0.587265
# weighted avg  0.439134   0.535810  0.587265  97467.0  0.500002  0.587265
# gender brblogset
#               f1-score  precision    recall  support       roc  accuracy
# Feminino      0.724028   0.779150  0.676190    840.0  0.148881  0.791927
# Masculino     0.833012   0.798817  0.870266   1241.0  0.851119  0.791927
# micro avg     0.791927   0.791927  0.791927   2081.0  0.500749  0.791927
# macro avg     0.778520   0.788983  0.773228   2081.0  0.500749  0.791927
# weighted avg  0.789020   0.790878  0.791927   2081.0  0.500749  0.791927
# gender pan13_es
# ...

# %%
showReports('education')
# Out:
# education esic
#                    f1-score  precision    recall  support       roc  accuracy
# Básico             0.505399   0.535383  0.478596  24154.0  0.767594  0.513154
# Pós-graduado       0.501632   0.549513  0.461427  31641.0  0.720721  0.513154
# Superior completo  0.525085   0.482251  0.576270  39157.0  0.604695  0.513154
# micro avg          0.513154   0.513154  0.513154  94952.0  0.697678  0.513154
# macro avg          0.510705   0.522382  0.505431  94952.0  0.697678  0.513154
# weighted avg       0.512262   0.518181  0.513154  94952.0  0.697678  0.513154
# education brblogset
#                      f1-score  precision    recall  support       roc  \
# Básico               0.368421   0.447674  0.313008    246.0  0.711050
# Pós-graduado         0.514689   0.461053  0.582447    376.0  0.675710
# Superior Completo    0.379085   0.371795  0.386667    375.0  0.556499
# Superior Incompleto  0.275000   0.300000  0.253846    260.0  0.602691
# ...

# %%
showReports('relig')
# Out:
# relig brmoral
#               f1-score  precision    recall  support  roc  accuracy
# r12           0.705570   0.545082  1.000000    133.0  0.5  0.545082
# r3            0.000000   0.000000  0.000000     90.0  0.5  0.545082
# r45           0.000000   0.000000  0.000000     21.0  0.5  0.545082
# micro avg     0.545082   0.545082  0.545082    244.0  0.5  0.545082
# macro avg     0.235190   0.181694  0.333333    244.0  0.5  0.545082
# weighted avg  0.384594   0.297114  0.545082    244.0  0.5  0.545082
# relig b5post
#               f1-score  precision    recall  support       roc  accuracy
# r12           0.686916   0.581028  0.840000    175.0  0.684939  0.551136
# r3            0.043011   0.142857  0.025316     79.0  0.531877  0.551136
# r45           0.491803   0.529412  0.459184     98.0  0.694962  0.551136
# micro avg     0.551136   0.551136  0.551136    352.0  0.639576  0.551136
# macro avg     0.407243   0.417766  0.441500    352.0  0.639576  0.551136
# ...

# %%
showReports('TI')
# Out:
# TI brmoral
#               f1-score  precision    recall  support       roc  accuracy
# N             0.379310   0.492537  0.308411    107.0  0.339535  0.667692
# S             0.773109   0.713178  0.844037    218.0  0.660465  0.667692
# micro avg     0.667692   0.667692  0.667692    325.0  0.505252  0.667692
# macro avg     0.576210   0.602858  0.576224    325.0  0.505252  0.667692
# weighted avg  0.643459   0.640536  0.667692    325.0  0.505252  0.667692
# TI b5post
#               f1-score  precision    recall  support       roc  accuracy
# no            0.763285   0.721461  0.810256    390.0  0.235555  0.699387
# yes           0.588235   0.654206  0.534351    262.0  0.764445  0.699387
# micro avg     0.699387   0.699387  0.699387    652.0  0.502202  0.699387
# macro avg     0.675760   0.687833  0.672304    652.0  0.502202  0.699387
# weighted avg  0.692943   0.694435  0.699387    652.0  0.502202  0.699387

# %%
showReports('professional')
# Out:
# professional esic
#                   f1-score  precision    recall  support       roc  accuracy
# Acadêmico         0.541311   0.528807  0.554420  21720.0  0.741806  0.474775
# CLT               0.395891   0.401351  0.390576  16427.0  0.699224  0.474775
# Empreendedor      0.295137   0.364414  0.247992  11331.0  0.716742  0.474775
# Servidor público  0.537022   0.505633  0.572566  22731.0  0.723025  0.474775
# micro avg         0.474775   0.474775  0.474775  72209.0  0.720209  0.474775
# macro avg         0.442340   0.450052  0.441389  72209.0  0.720209  0.474775
# weighted avg      0.468249   0.466720  0.474775  72209.0  0.720209  0.474775

# %%
showReports('region')
# Out:
# region esic
#               f1-score  precision    recall  support       roc  accuracy
# CO            0.409969   0.553620  0.325507  15035.0  0.747634  0.588387
# N             0.361292   0.590259  0.260314   5866.0  0.767080  0.588387
# NE            0.516336   0.630697  0.437082  18079.0  0.797329  0.588387
# S             0.359511   0.604564  0.255818  12634.0  0.745094  0.588387
# SE            0.699918   0.583713  0.873892  44882.0  0.753279  0.588387
# micro avg     0.588387   0.588387  0.588387  96496.0  0.762090  0.588387
# macro avg     0.469405   0.592571  0.430522  96496.0  0.762090  0.588387
# weighted avg  0.555192   0.590955  0.588387  96496.0  0.762090  0.588387

# %%
showReports('polit')
# Out:
# polit brmoral
#               f1-score  precision    recall  support       roc  accuracy
# p12           0.635193   0.611570  0.660714    112.0  0.772217  0.547692
# p3            0.530120   0.515625  0.545455    121.0  0.666099  0.547692
# p45           0.452381   0.500000  0.413043     92.0  0.687348  0.547692
# micro avg     0.547692   0.547692  0.547692    325.0  0.711101  0.547692
# macro avg     0.539232   0.542398  0.539737    325.0  0.711101  0.547692
# weighted avg  0.544324   0.544266  0.547692    325.0  0.711101  0.547692
