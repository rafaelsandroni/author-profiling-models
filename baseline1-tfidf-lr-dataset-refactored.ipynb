# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from utils.grid_baseline1 import run
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %% [markdown]
# ### Polit

# %%
run('polit')
# Out:
# brmoral
# training (325, 3)
# test (82, 3)
# training after cleaning (325, 3)
# test after cleaning (82, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# done in 91.060s
#
# Best score: 0.554
# Best parameters set:
# 	clf__C: 10000.0
# 	clf__penalty: 'l1'
# 	vect__max_df: 0.8
# 	vect__max_features: 3000
#
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.44      0.48        36
#           1       0.34      0.39      0.36        31
#           2       0.29      0.33      0.31        15
#
# avg / total       0.42      0.40      0.41        82
#
# >> accuracy 0.4024390243902439
# >> f1_score 0.4074972283813747
# [[16 15  5]
#  [12 12  7]
#  [ 2  8  5]]
# (82, 3) (82, 3)
# + ------------------------------------------------------------ +

# %% [markdown]
# ### Relig

# %%
run('relig')
# Out:
# b5post
# training (352, 3)
# test (89, 3)
# training after cleaning (352, 3)
# test after cleaning (89, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# done in 447.899s
#
# Best score: 0.577
# Best parameters set:
# 	clf__C: 10000.0
# 	clf__penalty: 'l2'
# 	vect__max_df: 0.8
# 	vect__max_features: None
#
#
#              precision    recall  f1-score   support
#
#           0       0.61      0.90      0.73        42
#           1       0.00      0.00      0.00        17
#           2       0.57      0.43      0.49        30
#
# avg / total       0.48      0.57      0.51        89
#
# >> accuracy 0.5730337078651685
# >> f1_score 0.5102167283638558
# [[38  2  2]
#  [ 9  0  8]
#  [15  2 13]]
# (89, 3) (89, 3)
# + ------------------------------------------------------------ +
#
# brmoral
# training (244, 3)
# test (62, 3)
# training after cleaning (244, 3)
# test after cleaning (62, 3)
# >> classifying
# Performing grid search...
# ...

# %% [markdown]
# ### Education

# %%
run('education')
# Out:
# esic
# training (94952, 3)
# test (23739, 3)
# training after cleaning (94952, 3)
# test after cleaning (23739, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# done in 48212.065s
#
# Best score: 0.509
# Best parameters set:
# 	clf__C: 4285.7143428571435
# 	clf__penalty: 'l2'
# 	vect__max_df: 0.8
# 	vect__max_features: 1000
#
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.47      0.50      5915
#           1       0.55      0.45      0.49      7965
#           2       0.49      0.59      0.53      9859
#
# avg / total       0.52      0.51      0.51     23739
#
# >> accuracy 0.5119423733097435
# >> f1_score 0.5103771927852202
# [[2789  601 2525]
#  [ 774 3580 3611]
#  [1720 2355 5784]]
# (23739, 3) (23739, 3)
# + ------------------------------------------------------------ +
#
# brmoral
# training (325, 3)
# test (82, 3)
# training after cleaning (325, 3)
# test after cleaning (82, 3)
# >> classifying
# ...

# %% [markdown]
# ### Region

# %%
run('region')
# Out:
# esic
# training (96496, 3)
# test (24125, 3)
# training after cleaning (96496, 3)
# test after cleaning (24125, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# done in 22622.010s
#
# Best score: 0.580
# Best parameters set:
# 	clf__C: 1428.5715142857143
# 	clf__penalty: 'l2'
# 	vect__max_df: 0.8
# 	vect__max_features: 3000
#
#
#              precision    recall  f1-score   support
#
#           0       0.57      0.33      0.42      3761
#           1       0.62      0.26      0.37      1427
#           2       0.64      0.44      0.52      4382
#           3       0.64      0.25      0.36      3306
#           4       0.58      0.89      0.70     11249
#
# avg / total       0.60      0.59      0.56     24125
#
# >> accuracy 0.5944870466321244
# >> f1_score 0.5600401444316797
# [[1246   48  243  108 2116]
#  [ 112  377  160   45  733]
#  [ 194   63 1922   74 2129]
#  [ 167   30  158  835 2116]
#  [ 449   91  498  249 9962]]
# ...

# %% [markdown]
# ### profession

# %%
run('professional')
# Out:
# esic
# training (72209, 3)
# test (18053, 3)
# training after cleaning (72209, 3)
# test after cleaning (18053, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# done in 14110.407s
#
# Best score: 0.461
# Best parameters set:
# 	clf__C: 10000.0
# 	clf__penalty: 'l2'
# 	vect__max_df: 0.8
# 	vect__max_features: 3000
#
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.55      0.54      5373
#           1       0.40      0.39      0.39      4139
#           2       0.37      0.26      0.30      2823
#           3       0.51      0.58      0.54      5718
#
# avg / total       0.47      0.48      0.47     18053
#
# >> accuracy 0.4759873705201352
# >> f1_score 0.4694775993378807
# [[2974  792  299 1308]
#  [ 965 1595  517 1062]
#  [ 490  809  720  804]
#  [1225  803  386 3304]]
# (18053, 4) (18053, 4)
# + ------------------------------------------------------------ +

# %% [markdown]
# ### TI

# %%
run('TI')
# Out:
# b5post
# training (652, 3)
# test (163, 3)
# training after cleaning (652, 3)
# test after cleaning (163, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f02a5273d76e> in <module>()
# ----> 1 run('TI')
#
# ~/drive/Models/utils/grid_baseline1.py in run(task)
#     194         del(df_training)
#     195
# --> 196         (acc, f1, cm) = grid(X_train, X_test, y_train, y_test, n_classes)
#     197         print()
#     198
#
# ~/drive/Models/utils/grid_baseline1.py in grid(X_train, X_test, y_train, y_test, n_classes)
#     102     t0 = time()
#     103
# --> 104     grid_search.fit(X_train, y_train)
#     105     print("done in %0.3fs" % (time() - t0))
#     106     print()
#
# ...

# %% [markdown]
# ### Age

# %%
run('age')
# Out:
# b5post
# training (413, 3)
# test (104, 3)
# training after cleaning (413, 3)
# test after cleaning (104, 3)
# >> classifying
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-28cb7968ea3b> in <module>()
# ----> 1 run('age')
#
# ~/drive/Models/utils/grid_baseline1.py in run(task)
#     194         del(df_training)
#     195
# --> 196         (acc, f1, cm) = grid(X_train, X_test, y_train, y_test, n_classes)
#     197         print()
#     198
#
# ~/drive/Models/utils/grid_baseline1.py in grid(X_train, X_test, y_train, y_test, n_classes)
#     102     t0 = time()
#     103
# --> 104     grid_search.fit(X_train, y_train)
#     105     print("done in %0.3fs" % (time() - t0))
#     106     print()
#
# ...

# %% [markdown]
# ### Gender

# %%
run('gender')
