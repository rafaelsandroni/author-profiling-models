# %%
# Package imports 
import matplotlib.pyplot as plt 
import numpy as np 
import sklearn 
import sklearn.datasets 
import sklearn.linear_model 
import matplotlib 
 
# Display plots inline and change default figure size 
# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# !ls '../../Data/Dataframe/full/'
# Out:
# b5post.csv	 brmoral.csv	      esic.csv	   esic_v4.csv
# brblogset.csv	 enblogs.csv	      esic_v2.csv  pan13_test.csv
# BRmoral-433.csv  e-sic-CA-rafael.csv  esic_v3.csv  smsCorpus.csv

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from nltk.corpus import stopwords

import pandas as pd
df = pd.read_csv('../../Data/Dataframe/full/b5post.csv')
df.head()

df2 = df[~pd.isnull(df.age)]
print(len(df), len(df2))

text = df2.text.values
y = df2.age.values

vect = TfidfVectorizer(lowercase=True,analyzer='word', smooth_idf=True, max_features=None, stop_words=set(stopwords.words('portuguese')))
X = vect.fit_transform(text).toarray()

from sklearn import preprocessing

def labelEncoder(y):
    le = LabelEncoder()
    le.fit(y)

    # print('>> classes', list(le.classes_))

    return (le.transform(y), len(le.classes_), le.classes_)

y, n_classes, c = labelEncoder(y)
# Out:
# 1020 517

# %%
print(X.shape, y.shape)

from sklearn.decomposition import PCA

pca = PCA(n_components=4)

X_pca = pca.fit_transform(X)

print(X.shape, y.shape)

# Generate a dataset and plot it
np.random.seed(0)
#X, y = datasets.make_moons(200, noise=0.20)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap=plt.cm.Spectral)
# Out:
# (517, 58470) (517,)
# (517, 58470) (517,)

# %%
def plot_decision_boundary(pred_func): 
    # Set min and max values and give it some padding 
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5 
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5 
    h = 0.01
    
    print(x_min, x_max, h)
    # Generate a grid of points with distance h between them 
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h)) 
    print(xx.shape, yy.shape, xx.ravel().shape, yy.ravel().shape)
    # Predict the function value for the whole gid 
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    print(Z.shape)
    Z = Z.reshape(Z.shape[0], 1)
    # Plot the contour and training examples 
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %%
X = X_pca
y = y


# Train the logistic rgeression classifier
clf = sklearn.linear_model.LogisticRegressionCV(cv=3, max_iter=120, solver='liblinear', multi_class='auto')
clf.fit(X, y)
 
# %% 12 
# Plot the decision boundary 
plot_decision_boundary(lambda x: clf.predict(X)) 
plt.title("Logistic Regression")
# Out:
# -0.7716857671746755 1.005305428042675 0.01
# (177, 178) (177, 178) (31506,) (31506,)
# (517,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-27754c4e94a8> in <module>()
#       9 # %% 12
#      10 # Plot the decision boundary
# ---> 11 plot_decision_boundary(lambda x: clf.predict(X))
#      12 plt.title("Logistic Regression")
#
# <ipython-input-69-5d9ab322f396> in plot_decision_boundary(pred_func)
#      17     Z = Z.reshape(Z.shape[0], 1)
#      18     # Plot the contour and training examples
# ---> 19     plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
#      20     plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)
#      21
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in contourf(*args, **kwargs)
#    2872                       mplDeprecation)
#    2873     try:
# -> 2874         ret = ax.contourf(*args, **kwargs)
#    2875     finally:
#    2876         ax._hold = washold
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in contourf(self, *args, **kwargs)
#    5833             self.cla()
#    5834         kwargs['filled'] = True
# -> 5835         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    5836         self.autoscale_view()
#    5837         return contours
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/contour.py in __init__(self, ax, *args, **kwargs)
#     862         self._transform = kwargs.get('transform', None)
#     863
# --> 864         self._process_args(*args, **kwargs)
#     865         self._process_levels()
#     866
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1427                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1428
# -> 1429             x, y, z = self._contour_args(args, kwargs)
#    1430
#    1431             _mask = ma.getmask(z)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1506             args = args[1:]
#    1507         elif Nargs <= 4:
# -> 1508             x, y, z = self._check_xyz(args[:3], kwargs)
#    1509             args = args[3:]
#    1510         else:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1564             if x.shape != z.shape:
#    1565                 raise TypeError("Shape of x does not match that of z: found "
# -> 1566                                 "{0} instead of {1}.".format(x.shape, z.shape))
#    1567
#    1568             if y.shape != z.shape:
#
# TypeError: Shape of x does not match that of z: found (177, 178) instead of (517, 1).
